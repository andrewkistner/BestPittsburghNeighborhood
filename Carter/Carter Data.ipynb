# %%
import pandas as pd

bud = pd.read_csv("education-income.csv")
bud.head(10)
# Out:
#         Neighborhood  Sector # Population (2010)  \
# 0   Allegheny Center         3               933
# 1     Allegheny West         3               462
# 2          Allentown         6             2,500
# 3          Arlington         7             1,869
# 4  Arlington Heights         7               244
# 5         Banksville         5             4,144
# 6  Bedford Dwellings        15             1,202
# 7          Beechview         5             7,974
# 8        Beltzhoover         6             1,925
# 9         Bloomfield        12             8,442
#
#   Total Pop, 25 and older (2010)  \
# 0                            609
# 1                            239
# 2                          1,729
# 3                          1,232
# 4                            166
# 5                          3,935
# 6                            733
# 7                          5,211
# 8                          1,369
# 9                          6,671
#
# ...

# %%
amt = pd.read_csv("education-income.csv", index_col = "Neighborhood")
salsrt = amt["2009 Med. Income ('13 Dollars)"].sort_values(ascending = False)
amtsrt.head(10)
# Out:
# Neighborhood
# Point Breeze           $95,704
# Squirrel Hill North    $91,409
# New Homestead          $90,652
# North Shore            $90,089
# Regent Square          $84,635
# Swisshelm Park         $79,025
# Strip District         $70,706
# Highland Park          $66,985
# Ridgemont              $61,313
# Squirrel Hill South    $59,376
# Name: 2009 Med. Income ('13 Dollars), dtype: object

# %%
spt = amt.plot.scatter(x = "Est. Pop. Under Poverty (2010)", y = "Population (2010)")
